# %% [markdown]
# # **Employee Retriction Prediction (Part 1. EDA)**
# Final Project Purwadhika JCDS-10
#
# Cahyo Pambudi Utomo

# %% [markdown]
# # Background
#
# This project is a final project from Job Connector Data Science Program in Purwadhika, dataset in this project is taken from Kaggle (link: https://www.kaggle.com/vjchoudhary7/hr-analytics-case-study).

# %% [markdown]
# # Problems
#
# Quoted from kaggle:
#
# A large company named XYZ, employs, at any given point of time, around 4000 employees. However, every year, around 15% of its employees leave the company and need to be replaced with the talent pool available in the job market. The management believes that this level of attrition (employees leaving, either on their own or because they got fired) is bad for the company, because of the following reasons -
#
# The former employees’ projects get delayed, which makes it difficult to meet timelines, resulting in a reputation loss among consumers and partners
# A sizeable department has to be maintained, for the purposes of recruiting new talent
# More often than not, the new employees have to be trained for the job and/or given time to acclimatise themselves to the company
# Hence, the management has contracted an HR analytics firm to understand what factors they should focus on, in order to curb attrition. In other words, they want to know what changes they should make to their workplace, in order to get most of their employees to stay. Also, they want to know which of these variables is most important and needs to be addressed right away.
#
# Since you are one of the star analysts at the firm, this project has been given to you.

# %% [markdown]
# # Goals
#
# - Taking insight from database
# - Making model to predict employee attrition in the future
# - Finding room for improvement and suggestion to company

# %% [markdown]
# # Importing Library

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Dataset

# %% [markdown]
# We got 6 datasets for this project, the datasets are:
#     1. data_dictionary (contains the explanation for each columns)
#     2. employee_survey_data
#     3. general_data
#     4. in_time
#     5. manager_survey_data
#     6. out_time

# %%
dict= pd.read_excel('/Users/cahyopambudiutomo/Documents/Purwadhika/Final Project/JCDS Cahyo/Dataset/data_dictionary.xlsx')
dict
# Out:
#                     Variable  \
# 0                        Age
# 1                  Attrition
# 2             BusinessTravel
# 3                 Department
# 4           DistanceFromHome
# 5                  Education
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10            EducationField
# 11             EmployeeCount
# 12            EmployeeNumber
# 13   EnvironmentSatisfaction
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                    Gender
# 18            JobInvolvement
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                  JobLevel
# 23                   JobRole
# 24           JobSatisfaction
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28             MaritalStatus
# 29             MonthlyIncome
# 30        NumCompaniesWorked
# ...

# %% [markdown]
# # Data Explanation
#
# - Age 		                = Age of the employee
# - Attrition	                = Whether the employee left in the previous year or not
# - BusinessTravel	        = How frequently the employees travelled for business purposes in the last year
# - Department	            = Department in company
# - DistanceFromHome          = Distance from home in kms
# - Education	                = Education Level:
# 		                  1 'Below College'
# 		                  2 'College'
# 		                  3 'Bachelor'
# 		                  4 'Master'
# 		                  5 'Doctor'
# - EducationField	        = Field of education
# - EmployeeCount	            = Employee count
# - EmployeeNumber	        = Employee number/id
# - EnvironmentSatisfaction	= Work Environment Satisfaction Level:
#                           1 'Low'
#                           2 'Medium'
#                           3 'High'
#                           4 'Very High'
# - Gender	                = Gender of employee
# - JobInvolvement	        = Job Involvement Level:
#                           1 'Low'
#                           2 'Medium'
#                           3 'High'
#                           4 'Very High'
# - JobLevel	                = Job level at company on a scale of 1 to 5
# - JobRole	                = Name of job role in company
# - JobSatisfaction	        = Job Satisfaction Level:
#                           1 'Low'
# 		                  2 'Medium'
# 		                  3 'High'
# 		                  4 'Very High'
# - MaritalStatus	            = Marital status of the employee
# - MonthlyIncome	            = Monthly income in rupees per month
# - NumCompaniesWorked	    = Total number of companies the employee has worked for
# - Over18	                = Whether the employee is above 18 years of age or not
# - PercentSalaryHike	        = Percent salary hike for last year
# - PerformanceRating	        = Performance rating for last year
#                           1 'Low'
# 		                  2 'Good'
# 		                  3 'Excellent'
# 		                  4 'Outstanding'
# - RelationshipSatisfaction  = Relationship satisfaction level
#                           1 'Low'
# 		                  2 'Medium'
# 		                  3 'High'
# 		                  4 'Very High'
# - StandardHours	            = Standard hours of work for the employee
# - StockOptionLevel	        = Stock option level of the employee
# - TotalWorkingYears	        = Total number of years the employee has worked so far
# - TrainingTimesLastYear	    = Number of times training was conducted for this employee last year
# - WorkLifeBalance	        = Work life balance level:
#                           1 'Bad'
# 		                  2 'Good'
# 		                  3 'Better'
# 		                  4 'Best'
# - YearsAtCompany	        = Total number of years spent at the company by the employee
# - YearsSinceLastPromotion	= Number of years since last promotion
# - YearsWithCurrManager	    = Number of years under current manager

# %% [markdown]
# ## Dataset employee_survey_data

# %%
esd_df= pd.read_csv('/Users/cahyopambudiutomo/Documents/Purwadhika/Final Project/JCDS Cahyo/Dataset/employee_survey_data.csv')

esd_df.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0

# %%
esd_df.shape
# Out:
# (4410, 4)

# %%
dfDesc = []

for i in esd_df.columns:
    dfDesc.append([
        i,
        esd_df[i].dtypes,
        esd_df[i].isna().sum(),
        (((esd_df[i].isna().sum()) / len(esd_df)) * 100).round(2),
        esd_df[i].nunique(),
        esd_df[i].drop_duplicates().sample(2).values
    ])

# %%
pd.DataFrame(dfDesc, columns= ['Data Features', 'Data Type', 'Null', 'Null (%)', 'Unique', 'Unique Sample'])
# Out:
#              Data Features Data Type  Null  Null (%)  Unique Unique Sample
# 0               EmployeeID     int64     0      0.00    4410  [2688, 4269]
# 1  EnvironmentSatisfaction   float64    25      0.57       4    [4.0, 2.0]
# 2          JobSatisfaction   float64    20      0.45       4    [2.0, 4.0]
# 3          WorkLifeBalance   float64    38      0.86       4    [3.0, 4.0]

# %%
esd_df.describe()
# Out:
#         EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# count  4410.000000              4385.000000      4390.000000      4372.000000
# mean   2205.500000                 2.723603         2.728246         2.761436
# std    1273.201673                 1.092756         1.101253         0.706245
# min       1.000000                 1.000000         1.000000         1.000000
# 25%    1103.250000                 2.000000         2.000000         2.000000
# 50%    2205.500000                 3.000000         3.000000         3.000000
# 75%    3307.750000                 4.000000         4.000000         3.000000
# max    4410.000000                 4.000000         4.000000         4.000000

# %% [markdown]
# ### Dataset general_data

# %%
gd_df= pd.read_csv('/Users/cahyopambudiutomo/Documents/Purwadhika/Final Project/JCDS Cahyo/Dataset/general_data.csv')

gd_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# 0          2  Life Sciences              1           1  Female         1
# 1          1  Life Sciences              1           2  Female         1
# 2          4          Other              1           3    Male         4
# 3          5  Life Sciences              1           4    Male         3
# 4          1        Medical              1           5    Male         1
#
# ...

# %%
gd_df.shape
# Out:
# (4410, 24)

# %%
dfDesc = []

for i in gd_df.columns:
    dfDesc.append([
        i,
        gd_df[i].dtypes,
        gd_df[i].isna().sum(),
        (((gd_df[i].isna().sum()) / len(gd_df)) * 100).round(2),
        gd_df[i].nunique(),
        gd_df[i].drop_duplicates().sample(1).values
    ])

# %%
pd.DataFrame(dfDesc, columns= ['Data Features', 'Data Type', 'Null', 'Null (%)', 'Unique', 'Unique Sample'])
# Out:
#               Data Features Data Type  Null  Null (%)  Unique  \
# 0                       Age     int64     0      0.00      43
# 1                 Attrition    object     0      0.00       2
# 2            BusinessTravel    object     0      0.00       3
# 3                Department    object     0      0.00       3
# 4          DistanceFromHome     int64     0      0.00      29
# 5                 Education     int64     0      0.00       5
# 6            EducationField    object     0      0.00       6
# 7             EmployeeCount     int64     0      0.00       1
# 8                EmployeeID     int64     0      0.00    4410
# 9                    Gender    object     0      0.00       2
# 10                 JobLevel     int64     0      0.00       5
# 11                  JobRole    object     0      0.00       9
# 12            MaritalStatus    object     0      0.00       3
# 13            MonthlyIncome     int64     0      0.00    1349
# ...

# %%
gd_df.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
gd_df.describe(include='O')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       4410           4410                    4410           4410   4410
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        3699           3129                    2883           1818   2646
#
#                 JobRole MaritalStatus Over18
# count              4410          4410   4410
# unique                9             3      1
# top     Sales Executive       Married      Y
# freq                978          2019   4410

# %% [markdown]
# ### Dataset manager_survey_data

# %%
msd_df= pd.read_csv('/Users/cahyopambudiutomo/Documents/Purwadhika/Final Project/JCDS Cahyo/Dataset/manager_survey_data.csv')

msd_df.head()
# Out:
#    EmployeeID  JobInvolvement  PerformanceRating
# 0           1               3                  3
# 1           2               2                  4
# 2           3               3                  3
# 3           4               2                  3
# 4           5               3                  3

# %%
msd_df.shape
# Out:
# (4410, 3)

# %%
dfDesc = []

for i in msd_df.columns:
    dfDesc.append([
        i,
        msd_df[i].dtypes,
        msd_df[i].isna().sum(),
        (((msd_df[i].isna().sum()) / len(msd_df)) * 100).round(2),
        msd_df[i].nunique(),
        msd_df[i].drop_duplicates().sample(2).values
    ])

# %%
pd.DataFrame(dfDesc, columns= ['Data Features', 'Data Type', 'Null', 'Null (%)', 'Unique', 'Unique Sample'])
# Out:
#        Data Features Data Type  Null  Null (%)  Unique Unique Sample
# 0         EmployeeID     int64     0       0.0    4410  [2668, 1919]
# 1     JobInvolvement     int64     0       0.0       4        [2, 1]
# 2  PerformanceRating     int64     0       0.0       2        [4, 3]

# %%
msd_df.describe()
# Out:
#         EmployeeID  JobInvolvement  PerformanceRating
# count  4410.000000     4410.000000        4410.000000
# mean   2205.500000        2.729932           3.153741
# std    1273.201673        0.711400           0.360742
# min       1.000000        1.000000           3.000000
# 25%    1103.250000        2.000000           3.000000
# 50%    2205.500000        3.000000           3.000000
# 75%    3307.750000        3.000000           3.000000
# max    4410.000000        4.000000           4.000000

# %% [markdown]
# ### Dataset in_time and out_time

# %%
in_df= pd.read_csv('/Users/cahyopambudiutomo/Documents/Purwadhika/Final Project/JCDS Cahyo/Dataset/in_time.csv')

in_df.head()
# Out:
#    Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         NaN  2015-01-02 09:43:45  2015-01-05 10:08:48
# 1           2         NaN  2015-01-02 10:15:44  2015-01-05 10:21:05
# 2           3         NaN  2015-01-02 10:17:41  2015-01-05 09:50:50
# 3           4         NaN  2015-01-02 10:05:06  2015-01-05 09:56:32
# 4           5         NaN  2015-01-02 10:28:17  2015-01-05 09:49:58
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 09:54:26  2015-01-07 09:34:31  2015-01-08 09:51:09
# 1                  NaN  2015-01-07 09:45:17  2015-01-08 10:09:04
# 2  2015-01-06 10:14:13  2015-01-07 09:47:27  2015-01-08 10:03:40
# 3  2015-01-06 10:11:07  2015-01-07 09:37:30  2015-01-08 10:02:08
# 4  2015-01-06 09:45:28  2015-01-07 09:49:37  2015-01-08 10:19:44
#
#             2015-01-09           2015-01-12           2015-01-13  2015-01-14  \
# 0  2015-01-09 10:09:25  2015-01-12 09:42:53  2015-01-13 10:13:06         NaN
# ...

# %%
out_df= pd.read_csv('/Users/cahyopambudiutomo/Documents/Purwadhika/Final Project/JCDS Cahyo/Dataset/out_time.csv')

out_df.head()
# Out:
#    Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         NaN  2015-01-02 16:56:15  2015-01-05 17:20:11
# 1           2         NaN  2015-01-02 18:22:17  2015-01-05 17:48:22
# 2           3         NaN  2015-01-02 16:59:14  2015-01-05 17:06:46
# 3           4         NaN  2015-01-02 17:25:24  2015-01-05 17:14:03
# 4           5         NaN  2015-01-02 18:31:37  2015-01-05 17:49:15
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 17:19:05  2015-01-07 16:34:55  2015-01-08 17:08:32
# 1                  NaN  2015-01-07 17:09:06  2015-01-08 17:34:04
# 2  2015-01-06 16:38:32  2015-01-07 16:33:21  2015-01-08 17:24:22
# 3  2015-01-06 17:07:42  2015-01-07 16:32:40  2015-01-08 16:53:11
# 4  2015-01-06 17:26:25  2015-01-07 17:37:59  2015-01-08 17:59:28
#
#             2015-01-09           2015-01-12           2015-01-13  2015-01-14  \
# 0  2015-01-09 17:38:29  2015-01-12 16:58:39  2015-01-13 18:02:58         NaN
# ...

# %%
print(in_df.shape)
print(out_df.shape)
# Out:
# (4410, 262)
# (4410, 262)

# %% [markdown]
# > There is a column with no title in in_time and out_time dataset, after analyzing the data, lets assume that is a column for EmployeeId
#
# > We can also find there are many missing values in data (assume missing value is when the employee not come to work) and there are few columns with all NaN values

# %%
# Handling Missing Values

in_df= in_df.replace(np.nan,0)
in_df.head()
# Out:
#    Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         0.0  2015-01-02 09:43:45  2015-01-05 10:08:48
# 1           2         0.0  2015-01-02 10:15:44  2015-01-05 10:21:05
# 2           3         0.0  2015-01-02 10:17:41  2015-01-05 09:50:50
# 3           4         0.0  2015-01-02 10:05:06  2015-01-05 09:56:32
# 4           5         0.0  2015-01-02 10:28:17  2015-01-05 09:49:58
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 09:54:26  2015-01-07 09:34:31  2015-01-08 09:51:09
# 1                    0  2015-01-07 09:45:17  2015-01-08 10:09:04
# 2  2015-01-06 10:14:13  2015-01-07 09:47:27  2015-01-08 10:03:40
# 3  2015-01-06 10:11:07  2015-01-07 09:37:30  2015-01-08 10:02:08
# 4  2015-01-06 09:45:28  2015-01-07 09:49:37  2015-01-08 10:19:44
#
#             2015-01-09           2015-01-12           2015-01-13  2015-01-14  \
# 0  2015-01-09 10:09:25  2015-01-12 09:42:53  2015-01-13 10:13:06         0.0
# ...

# %%
out_df= out_df.replace(np.nan,0)
out_df.head()
# Out:
#    Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         0.0  2015-01-02 16:56:15  2015-01-05 17:20:11
# 1           2         0.0  2015-01-02 18:22:17  2015-01-05 17:48:22
# 2           3         0.0  2015-01-02 16:59:14  2015-01-05 17:06:46
# 3           4         0.0  2015-01-02 17:25:24  2015-01-05 17:14:03
# 4           5         0.0  2015-01-02 18:31:37  2015-01-05 17:49:15
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 17:19:05  2015-01-07 16:34:55  2015-01-08 17:08:32
# 1                    0  2015-01-07 17:09:06  2015-01-08 17:34:04
# 2  2015-01-06 16:38:32  2015-01-07 16:33:21  2015-01-08 17:24:22
# 3  2015-01-06 17:07:42  2015-01-07 16:32:40  2015-01-08 16:53:11
# 4  2015-01-06 17:26:25  2015-01-07 17:37:59  2015-01-08 17:59:28
#
#             2015-01-09           2015-01-12           2015-01-13  2015-01-14  \
# 0  2015-01-09 17:38:29  2015-01-12 16:58:39  2015-01-13 18:02:58         0.0
# ...

# %%
# Filling 0 value and making same format data
in_df.iloc[:, 1:] = in_df.iloc[:, 1:].apply(pd.to_datetime, errors='coerce')
out_df.iloc[:, 1:] = out_df.iloc[:, 1:].apply(pd.to_datetime, errors='coerce')

# %%
in_df.head()
# Out:
#    Unnamed: 0 2015-01-01          2015-01-02          2015-01-05  \
# 0           1 1970-01-01 2015-01-02 09:43:45 2015-01-05 10:08:48
# 1           2 1970-01-01 2015-01-02 10:15:44 2015-01-05 10:21:05
# 2           3 1970-01-01 2015-01-02 10:17:41 2015-01-05 09:50:50
# 3           4 1970-01-01 2015-01-02 10:05:06 2015-01-05 09:56:32
# 4           5 1970-01-01 2015-01-02 10:28:17 2015-01-05 09:49:58
#
#            2015-01-06          2015-01-07          2015-01-08  \
# 0 2015-01-06 09:54:26 2015-01-07 09:34:31 2015-01-08 09:51:09
# 1 1970-01-01 00:00:00 2015-01-07 09:45:17 2015-01-08 10:09:04
# 2 2015-01-06 10:14:13 2015-01-07 09:47:27 2015-01-08 10:03:40
# 3 2015-01-06 10:11:07 2015-01-07 09:37:30 2015-01-08 10:02:08
# 4 2015-01-06 09:45:28 2015-01-07 09:49:37 2015-01-08 10:19:44
#
#            2015-01-09          2015-01-12          2015-01-13 2015-01-14  \
# 0 2015-01-09 10:09:25 2015-01-12 09:42:53 2015-01-13 10:13:06 1970-01-01
# ...

# %%
out_df.head()
# Out:
#    Unnamed: 0 2015-01-01          2015-01-02          2015-01-05  \
# 0           1 1970-01-01 2015-01-02 16:56:15 2015-01-05 17:20:11
# 1           2 1970-01-01 2015-01-02 18:22:17 2015-01-05 17:48:22
# 2           3 1970-01-01 2015-01-02 16:59:14 2015-01-05 17:06:46
# 3           4 1970-01-01 2015-01-02 17:25:24 2015-01-05 17:14:03
# 4           5 1970-01-01 2015-01-02 18:31:37 2015-01-05 17:49:15
#
#            2015-01-06          2015-01-07          2015-01-08  \
# 0 2015-01-06 17:19:05 2015-01-07 16:34:55 2015-01-08 17:08:32
# 1 1970-01-01 00:00:00 2015-01-07 17:09:06 2015-01-08 17:34:04
# 2 2015-01-06 16:38:32 2015-01-07 16:33:21 2015-01-08 17:24:22
# 3 2015-01-06 17:07:42 2015-01-07 16:32:40 2015-01-08 16:53:11
# 4 2015-01-06 17:26:25 2015-01-07 17:37:59 2015-01-08 17:59:28
#
#            2015-01-09          2015-01-12          2015-01-13 2015-01-14  \
# 0 2015-01-09 17:38:29 2015-01-12 16:58:39 2015-01-13 18:02:58 1970-01-01
# ...

# %%
# Join in and out data
time_df= in_df.append(out_df)

# %%
time_df.head()
# Out:
#    Unnamed: 0 2015-01-01          2015-01-02          2015-01-05  \
# 0           1 1970-01-01 2015-01-02 09:43:45 2015-01-05 10:08:48
# 1           2 1970-01-01 2015-01-02 10:15:44 2015-01-05 10:21:05
# 2           3 1970-01-01 2015-01-02 10:17:41 2015-01-05 09:50:50
# 3           4 1970-01-01 2015-01-02 10:05:06 2015-01-05 09:56:32
# 4           5 1970-01-01 2015-01-02 10:28:17 2015-01-05 09:49:58
#
#            2015-01-06          2015-01-07          2015-01-08  \
# 0 2015-01-06 09:54:26 2015-01-07 09:34:31 2015-01-08 09:51:09
# 1 1970-01-01 00:00:00 2015-01-07 09:45:17 2015-01-08 10:09:04
# 2 2015-01-06 10:14:13 2015-01-07 09:47:27 2015-01-08 10:03:40
# 3 2015-01-06 10:11:07 2015-01-07 09:37:30 2015-01-08 10:02:08
# 4 2015-01-06 09:45:28 2015-01-07 09:49:37 2015-01-08 10:19:44
#
#            2015-01-09          2015-01-12          2015-01-13 2015-01-14  \
# 0 2015-01-09 10:09:25 2015-01-12 09:42:53 2015-01-13 10:13:06 1970-01-01
# ...

# %%
time_df=time_df.diff(periods=4410)
time_df=time_df.iloc[4410:]
time_df.reset_index(inplace=True)
time_df.head()
# Out:
#    index  Unnamed: 0 2015-01-01 2015-01-02 2015-01-05 2015-01-06 2015-01-07  \
# 0      0         0.0     0 days   07:12:30   07:11:23   07:24:39   07:00:24
# 1      1         0.0     0 days   08:06:33   07:27:17   00:00:00   07:23:49
# 2      2         0.0     0 days   06:41:33   07:15:56   06:24:19   06:45:54
# 3      3         0.0     0 days   07:20:18   07:17:31   06:56:35   06:55:10
# 4      4         0.0     0 days   08:03:20   07:59:17   07:40:57   07:48:22
#
#   2015-01-08 2015-01-09 2015-01-12 2015-01-13 2015-01-14 2015-01-15  \
# 0   07:17:23   07:29:04   07:15:46   07:49:52     0 days   07:20:49
# 1   07:25:00   07:09:03   07:36:41   07:16:44     0 days   07:36:47
# 2   07:20:42   06:51:41   07:25:07   06:59:59     0 days   07:26:18
# 3   06:51:03   07:11:35   06:59:55   07:18:23     0 days   06:52:36
# 4   07:39:44   07:43:18   08:21:54   08:15:26     0 days   08:15:36
#
#   2015-01-16 2015-01-19 2015-01-20 2015-01-21 2015-01-22 2015-01-23  \
# ...

# %%
time_df.drop(columns=['index','Unnamed: 0'],axis=1,inplace=True)
time_df.head()
# Out:
#   2015-01-01 2015-01-02 2015-01-05 2015-01-06 2015-01-07 2015-01-08  \
# 0     0 days   07:12:30   07:11:23   07:24:39   07:00:24   07:17:23
# 1     0 days   08:06:33   07:27:17   00:00:00   07:23:49   07:25:00
# 2     0 days   06:41:33   07:15:56   06:24:19   06:45:54   07:20:42
# 3     0 days   07:20:18   07:17:31   06:56:35   06:55:10   06:51:03
# 4     0 days   08:03:20   07:59:17   07:40:57   07:48:22   07:39:44
#
#   2015-01-09 2015-01-12 2015-01-13 2015-01-14 2015-01-15 2015-01-16  \
# 0   07:29:04   07:15:46   07:49:52     0 days   07:20:49   07:16:03
# 1   07:09:03   07:36:41   07:16:44     0 days   07:36:47   07:43:39
# 2   06:51:41   07:25:07   06:59:59     0 days   07:26:18   07:12:37
# 3   07:11:35   06:59:55   07:18:23     0 days   06:52:36   06:54:28
# 4   07:43:18   08:21:54   08:15:26     0 days   08:15:36   08:24:13
#
#   2015-01-19 2015-01-20 2015-01-21 2015-01-22 2015-01-23 2015-01-26  \
# 0   00:00:00   06:46:33   07:05:42   07:03:02   07:36:17     0 days
# ...

# %%
# Drop columns contain NaN value on its whole column

time_df.drop(['2015-01-01', '2015-01-14','2015-01-26','2015-03-05','2015-05-01','2015-07-17',
              '2015-09-17','2015-10-02','2015-11-09','2015-11-10','2015-11-11','2015-12-25'
             ], axis = 1,inplace=True)

# %%
time_df['MeanTime']= time_df.mean(axis=1)

# %%
time_df['MeanTime'].head()
# Out:
# 0   06:52:12.823293
# 1   07:18:57.493975
# 2   06:48:57.891566
# 3   06:47:21.172690
# 4   07:52:39.220883
# Name: MeanTime, dtype: timedelta64[ns]

# %%
time_df.head()
# Out:
#   2015-01-02 2015-01-05 2015-01-06 2015-01-07 2015-01-08 2015-01-09  \
# 0   07:12:30   07:11:23   07:24:39   07:00:24   07:17:23   07:29:04
# 1   08:06:33   07:27:17   00:00:00   07:23:49   07:25:00   07:09:03
# 2   06:41:33   07:15:56   06:24:19   06:45:54   07:20:42   06:51:41
# 3   07:20:18   07:17:31   06:56:35   06:55:10   06:51:03   07:11:35
# 4   08:03:20   07:59:17   07:40:57   07:48:22   07:39:44   07:43:18
#
#   2015-01-12 2015-01-13 2015-01-15 2015-01-16 2015-01-19 2015-01-20  \
# 0   07:15:46   07:49:52   07:20:49   07:16:03   00:00:00   06:46:33
# 1   07:36:41   07:16:44   07:36:47   07:43:39   07:34:39   07:36:10
# 2   07:25:07   06:59:59   07:26:18   07:12:37   07:04:20   06:55:14
# 3   06:59:55   07:18:23   06:52:36   06:54:28   06:31:07   07:10:44
# 4   08:21:54   08:15:26   08:15:36   08:24:13   00:00:00   07:48:55
#
#   2015-01-21 2015-01-22 2015-01-23 2015-01-27 2015-01-28 2015-01-29  \
# 0   07:05:42   07:03:02   07:36:17   07:37:45   07:07:08   07:24:49
# ...

# %%
time_df['WorkingHours']= time_df['MeanTime']/ np.timedelta64(1, 'h')
time_df.head()
# Out:
#   2015-01-02 2015-01-05 2015-01-06 2015-01-07 2015-01-08 2015-01-09  \
# 0   07:12:30   07:11:23   07:24:39   07:00:24   07:17:23   07:29:04
# 1   08:06:33   07:27:17   00:00:00   07:23:49   07:25:00   07:09:03
# 2   06:41:33   07:15:56   06:24:19   06:45:54   07:20:42   06:51:41
# 3   07:20:18   07:17:31   06:56:35   06:55:10   06:51:03   07:11:35
# 4   08:03:20   07:59:17   07:40:57   07:48:22   07:39:44   07:43:18
#
#   2015-01-12 2015-01-13 2015-01-15 2015-01-16 2015-01-19 2015-01-20  \
# 0   07:15:46   07:49:52   07:20:49   07:16:03   00:00:00   06:46:33
# 1   07:36:41   07:16:44   07:36:47   07:43:39   07:34:39   07:36:10
# 2   07:25:07   06:59:59   07:26:18   07:12:37   07:04:20   06:55:14
# 3   06:59:55   07:18:23   06:52:36   06:54:28   06:31:07   07:10:44
# 4   08:21:54   08:15:26   08:15:36   08:24:13   00:00:00   07:48:55
#
#   2015-01-21 2015-01-22 2015-01-23 2015-01-27 2015-01-28 2015-01-29  \
# 0   07:05:42   07:03:02   07:36:17   07:37:45   07:07:08   07:24:49
# ...

# %%
time_df.reset_index(inplace= True)
time_df.head()
# Out:
#    index 2015-01-02 2015-01-05 2015-01-06 2015-01-07 2015-01-08 2015-01-09  \
# 0      0   07:12:30   07:11:23   07:24:39   07:00:24   07:17:23   07:29:04
# 1      1   08:06:33   07:27:17   00:00:00   07:23:49   07:25:00   07:09:03
# 2      2   06:41:33   07:15:56   06:24:19   06:45:54   07:20:42   06:51:41
# 3      3   07:20:18   07:17:31   06:56:35   06:55:10   06:51:03   07:11:35
# 4      4   08:03:20   07:59:17   07:40:57   07:48:22   07:39:44   07:43:18
#
#   2015-01-12 2015-01-13 2015-01-15 2015-01-16 2015-01-19 2015-01-20  \
# 0   07:15:46   07:49:52   07:20:49   07:16:03   00:00:00   06:46:33
# 1   07:36:41   07:16:44   07:36:47   07:43:39   07:34:39   07:36:10
# 2   07:25:07   06:59:59   07:26:18   07:12:37   07:04:20   06:55:14
# 3   06:59:55   07:18:23   06:52:36   06:54:28   06:31:07   07:10:44
# 4   08:21:54   08:15:26   08:15:36   08:24:13   00:00:00   07:48:55
#
#   2015-01-21 2015-01-22 2015-01-23 2015-01-27 2015-01-28 2015-01-29  \
# ...

# %%
time_df.drop(time_df.columns.difference(['index','WorkingHours']), 1, inplace= True)

# %%
time_df.rename(columns= {'index': 'EmployeeID'}, inplace= True)
time_df.head()
# Out:
#    EmployeeID  WorkingHours
# 0           0      6.870229
# 1           1      7.315971
# 2           2      6.816081
# 3           3      6.789215
# 4           4      7.877561

# %%
time_df['EmployeeID']= time_df['EmployeeID']+1
time_df.head()
# Out:
#    EmployeeID  WorkingHours
# 0           1      6.870229
# 1           2      7.315971
# 2           3      6.816081
# 3           4      6.789215
# 4           5      7.877561

# %% [markdown]
# # Merging 4 different datasets into one dataset
#
# 4 Datasets will be joined together using one common feature (EmployeeID) which is exists in all datasets.

# %%
data= pd.merge(esd_df,gd_df, how = 'inner') # esd_df and gd_df merged first
data= pd.merge(data,msd_df, how = 'inner') # merged with msd_df
data= pd.merge(data,time_df, how = 'inner') #merged with time_df

data.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  Age  \
# 0           1                      3.0              4.0              2.0   51
# 1           2                      3.0              2.0              4.0   31
# 2           3                      2.0              2.0              1.0   32
# 3           4                      4.0              4.0              3.0   38
# 4           5                      4.0              1.0              3.0   32
#
#   Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0        No      Travel_Rarely                   Sales                 6
# 1       Yes  Travel_Frequently  Research & Development                10
# 2        No  Travel_Frequently  Research & Development                17
# 3        No         Non-Travel  Research & Development                 2
# 4        No      Travel_Rarely  Research & Development                10
#
# ...

# %%
data.to_csv('/Users/cahyopambudiutomo/Documents/Purwadhika/Final Project/JCDS Cahyo/Dataset/data_merged.csv', index = False)

# %% [markdown]
# ## Checking dataset

# %%
data.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  Age  \
# 0           1                      3.0              4.0              2.0   51
# 1           2                      3.0              2.0              4.0   31
# 2           3                      2.0              2.0              1.0   32
# 3           4                      4.0              4.0              3.0   38
# 4           5                      4.0              1.0              3.0   32
#
#   Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0        No      Travel_Rarely                   Sales                 6
# 1       Yes  Travel_Frequently  Research & Development                10
# 2        No  Travel_Frequently  Research & Development                17
# 3        No         Non-Travel  Research & Development                 2
# 4        No      Travel_Rarely  Research & Development                10
#
# ...

# %%
data.shape
# Out:
# (4410, 30)

# %%
data.describe()
# Out:
#         EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# count  4410.000000              4385.000000      4390.000000      4372.000000
# mean   2205.500000                 2.723603         2.728246         2.761436
# std    1273.201673                 1.092756         1.101253         0.706245
# min       1.000000                 1.000000         1.000000         1.000000
# 25%    1103.250000                 2.000000         2.000000         2.000000
# 50%    2205.500000                 3.000000         3.000000         3.000000
# 75%    3307.750000                 4.000000         4.000000         3.000000
# max    4410.000000                 4.000000         4.000000         4.000000
#
#                Age  DistanceFromHome    Education  EmployeeCount     JobLevel  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0     2.063946
# ...

# %%
data.describe(include='O')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       4410           4410                    4410           4410   4410
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        3699           3129                    2883           1818   2646
#
#                 JobRole MaritalStatus Over18
# count              4410          4410   4410
# unique                9             3      1
# top     Sales Executive       Married      Y
# freq                978          2019   4410

# %%
dfDesc = []

for i in data.columns:
    dfDesc.append([
        i,
        data[i].dtypes,
        data[i].isna().sum(),
        (((data[i].isna().sum()) / len(data)) * 100).round(2),
        data[i].nunique(),
        data[i].drop_duplicates().sample(1).values
    ])

# %%
pd.DataFrame(dfDesc, columns= ['Data Features', 'Data Type', 'Null', 'Null (%)', 'Unique', 'Unique Sample'])
# Out:
#               Data Features Data Type  Null  Null (%)  Unique  \
# 0                EmployeeID     int64     0      0.00    4410
# 1   EnvironmentSatisfaction   float64    25      0.57       4
# 2           JobSatisfaction   float64    20      0.45       4
# 3           WorkLifeBalance   float64    38      0.86       4
# 4                       Age     int64     0      0.00      43
# 5                 Attrition    object     0      0.00       2
# 6            BusinessTravel    object     0      0.00       3
# 7                Department    object     0      0.00       3
# 8          DistanceFromHome     int64     0      0.00      29
# 9                 Education     int64     0      0.00       5
# 10           EducationField    object     0      0.00       6
# 11            EmployeeCount     int64     0      0.00       1
# 12                   Gender    object     0      0.00       2
# 13                 JobLevel     int64     0      0.00       5
# ...

# %% [markdown]
# # Handling Missing Values
#
# Based on data description before, we can see that this dataset contains missing values

# %%
null = data.isna().sum()
print(null[null>0])
# Out:
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# NumCompaniesWorked         19
# TotalWorkingYears           9
# dtype: int64

# %%
null_percentage = round(data.isna().sum() / len(data) *100,2)
print(null_percentage[null>0])
# Out:
# EnvironmentSatisfaction    0.57
# JobSatisfaction            0.45
# WorkLifeBalance            0.86
# NumCompaniesWorked         0.43
# TotalWorkingYears          0.20
# dtype: float64

# %% [markdown]
# ### Option 1: Drop Null Data
#
# As we can see, null values in this dataset is very low (even below 1% from the whole data), so it will only affect a little to the future analytics and model.
#
# Based on the fact before, we can decide to drop the null value

# %%
# data.dropna(inplace=True)

# %% [markdown]
# ### Option 2: Fill Null Data With Median Value
#
# We got 5 column with Null value on it. So we will fill it with median value to make sure the new data is not an outlier.

# %%
null = ['EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance', 'NumCompaniesWorked', 'TotalWorkingYears']
for i in null:
    data[i] = data[i].fillna(data[i].median())

# %%
data.isna().sum()
# Out:
# EmployeeID                 0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# JobInvolvement             0
# PerformanceRating          0
# WorkingHours               0
# dtype: int64

# %%
data.shape
# Out:
# (4410, 30)

# %%
# All data already clean from null values

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.describe()
# Out:
#         EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# count  4410.000000              4410.000000      4410.000000      4410.000000
# mean   2205.500000                 2.725170         2.729478         2.763492
# std    1273.201673                 1.089852         1.098904         0.703541
# min       1.000000                 1.000000         1.000000         1.000000
# 25%    1103.250000                 2.000000         2.000000         2.000000
# 50%    2205.500000                 3.000000         3.000000         3.000000
# 75%    3307.750000                 4.000000         4.000000         3.000000
# max    4410.000000                 4.000000         4.000000         4.000000
#
#                Age  DistanceFromHome    Education  EmployeeCount     JobLevel  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0     2.063946
# ...

# %%
data.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  Age  \
# 0           1                      3.0              4.0              2.0   51
# 1           2                      3.0              2.0              4.0   31
# 2           3                      2.0              2.0              1.0   32
# 3           4                      4.0              4.0              3.0   38
# 4           5                      4.0              1.0              3.0   32
#
#   Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0        No      Travel_Rarely                   Sales                 6
# 1       Yes  Travel_Frequently  Research & Development                10
# 2        No  Travel_Frequently  Research & Development                17
# 3        No         Non-Travel  Research & Development                 2
# 4        No      Travel_Rarely  Research & Development                10
#
# ...

# %%
for i in data.columns:
    print(i)
    print(data[i].unique())
# Out:
# EmployeeID
# [   1    2    3 ... 4408 4409 4410]
# EnvironmentSatisfaction
# [3. 2. 4. 1.]
# JobSatisfaction
# [4. 2. 1. 3.]
# WorkLifeBalance
# [2. 4. 1. 3.]
# Age
# [51 31 32 38 46 28 29 25 45 36 55 47 37 21 35 26 50 53 42 44 49 18 41 39
#  58 33 43 52 27 30 54 40 23 48 57 34 24 22 56 60 19 20 59]
# Attrition
# ['No' 'Yes']
# BusinessTravel
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Department
# ['Sales' 'Research & Development' 'Human Resources']
# DistanceFromHome
# [ 6 10 17  2  8 11 18  1  7 28 14  3  4 16  9  5 20 29 15 13 24 19 22 25
#  21 26 27 12 23]
# Education
# [2 1 4 5 3]
# EducationField
# ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# EmployeeCount
# [1]
# Gender
# ['Female' 'Male']
# JobLevel
# [1 4 3 2 5]
# JobRole
# ['Healthcare Representative' 'Research Scientist' 'Sales Executive'
#  'Human Resources' 'Research Director' 'Laboratory Technician'
#  'Manufacturing Director' 'Sales Representative' 'Manager']
# ...

# %%
# Drop 3 datas because these columns only contains one similar value

data.drop(['EmployeeCount', 'StandardHours', 'Over18'], axis=1, inplace=True)

# %%
# Check Outliers

# %%
numerical_columns= data.select_dtypes(exclude='object').columns
data_num= data[numerical_columns]
categorical_columns= data.select_dtypes(include='object').columns
data_cat= data[categorical_columns]

# %%
plt.figure(figsize=(20,18))
for index, item in enumerate(data_num, 1):
    plt.subplot(5, 4, index)
    sns.boxplot(data[item])
plt.show()

# %% [markdown]
# - As we can see from boxplot above, there are many outliers in the data. So we need to do something to make it nice and get more valid model.

# %%
Q1 = data.describe()['MonthlyIncome']['25%']
Q3 = data.describe()['MonthlyIncome']['75%']
IQR = Q3 - Q1
Upper_Fence = Q3 + (1.5 * IQR)
Lower_Fence = Q1 - (1.5 * IQR)
data[(data['MonthlyIncome'] < Lower_Fence) | (data['MonthlyIncome'] > Upper_Fence)]
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 2              3                      2.0              2.0              1.0
# 55            56                      4.0              2.0              3.0
# 56            57                      3.0              1.0              3.0
# 73            74                      3.0              2.0              3.0
# 76            77                      4.0              4.0              3.0
# ...          ...                      ...              ...              ...
# 4319        4320                      2.0              4.0              3.0
# 4320        4321                      1.0              4.0              4.0
# 4360        4361                      4.0              4.0              1.0
# 4377        4378                      3.0              4.0              3.0
# 4399        4400                      4.0              1.0              3.0
#
# ...

# %%
check= data[data["JobLevel"] > 4]
check
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 72            73                      3.0              3.0              4.0
# 97            98                      3.0              3.0              3.0
# 102          103                      4.0              3.0              3.0
# 105          106                      4.0              3.0              3.0
# 122          123                      4.0              3.0              4.0
# ...          ...                      ...              ...              ...
# 4301        4302                      2.0              2.0              3.0
# 4304        4305                      2.0              3.0              1.0
# 4334        4335                      2.0              2.0              2.0
# 4350        4351                      4.0              3.0              3.0
# 4361        4362                      4.0              1.0              3.0
#
# ...

# %% [markdown]
# - We can see that MonthlyIncome in this dataset is a bit weird. Because we can see there are employee in JobLevel 1 (lowest) has higher MonthlyIncome than employee in JobLevel 5.

# %%
Q1 = data.describe()['WorkingHours']['25%']
Q3 = data.describe()['WorkingHours']['75%']
IQR = Q3 - Q1
Upper_Fence = Q3 + (1.5 * IQR)
Lower_Fence = Q1 - (1.5 * IQR)
data[(data['WorkingHours'] < Lower_Fence) | (data['WorkingHours'] > Upper_Fence)]
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 17            18                      1.0              4.0              3.0
# 26            27                      1.0              1.0              3.0
# 28            29                      4.0              3.0              1.0
# 50            51                      4.0              3.0              3.0
# 56            57                      3.0              1.0              3.0
# ...          ...                      ...              ...              ...
# 4124        4125                      1.0              4.0              4.0
# 4163        4164                      4.0              3.0              3.0
# 4254        4255                      4.0              4.0              3.0
# 4315        4316                      3.0              4.0              1.0
# 4316        4317                      3.0              3.0              2.0
#
# ...

# %% [markdown]
# - We can see that outliers value in working hours is still make sense

# %% [markdown]
# # Univariate

# %%
percent= [data[data['Attrition'] == 'No']['Attrition'].count(), data[data['Attrition'] == 'Yes']['Attrition'].count()]
label= ['No','Yes']

attrition = pd.DataFrame(data['Attrition'].value_counts())
print(attrition)

plt.pie(percent,
       labels= label,
       colors= ['r', 'g'],
       radius= 1.1,
       textprops={
            'size': 20,
            'color': 'b'
        },
       autopct= '%1.1f%%',
       shadow= True,
       explode= (.1,.1))
plt.legend(data['Attrition'])
plt.title("Attrition Level", bbox={'facecolor':'0.8', 'pad':5})
plt.show()
# Out:
#      Attrition
# No        3699
# Yes        711

# %% [markdown]
# - From the Piechart above, we can see there are 16.1% (711) employees who left the company and 83.9% (3699) employees who stayed in company
# - The data is imbalanced

# %%
data.hist(figsize=(30,20),grid = False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fda0dfb11f0>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(18,6))

plt.subplot(1,3,1)
sns.distplot(data['Age'], color='red')
plt.xlim(10,70)
plt.title('Age Distribution')

plt.subplot(1,3,2)
data['MaritalStatus'].value_counts().plot(kind='bar', color='green')
plt.xticks(rotation=0)
plt.title('Marital Status Distribution')

plt.subplot(1,3,3)
sns.countplot(x='Gender',data=data)
plt.title('Gender Distribution')

plt.show()

# %% [markdown]
# - Age: Employee in this company is mostly in  age range 25-45
# - Marital Status: Most of the employees in this company already married
# - Gender: Male population is more dominating than female

# %%
data.dtypes
# Out:
# EmployeeID                   int64
# EnvironmentSatisfaction    float64
# JobSatisfaction            float64
# WorkLifeBalance            float64
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# Gender                      object
# JobLevel                     int64
# JobRole                     object
# MaritalStatus               object
# MonthlyIncome                int64
# NumCompaniesWorked         float64
# PercentSalaryHike            int64
# StockOptionLevel             int64
# TotalWorkingYears          float64
# TrainingTimesLastYear        int64
# YearsAtCompany               int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# JobInvolvement               int64
# PerformanceRating            int64
# WorkingHours               float64
# ...

# %%
plt.figure(figsize=(18,6))

plt.subplot(1,3,1)
data['Department'].value_counts().plot(kind='bar', color='cyan')
plt.xticks(rotation=0)
plt.title('Department Distribution')

plt.subplot(1,3,2)
data['JobRole'].value_counts().plot(kind='bar', color='magenta')
plt.title('Job Role Distribution')

plt.subplot(1,3,3)
data['EducationField'].value_counts().plot(kind='bar', color='yellow')
plt.title('Education Field Distribution')

plt.show()

# %% [markdown]
# - Department: R & D department has the most employees and human resources has the least employees
# - Job Role: Sales executive role is dominating in this company
# - Education Field: Many people in this company studied life sciences and medical

# %%
plt.figure(figsize=(18,6))

plt.subplot(1,3,1)
sns.countplot(x='BusinessTravel',data=data)
plt.title('Business Travel')

plt.subplot(1,3,2)
data['JobLevel'].value_counts().plot(kind='bar', color='red')
plt.xticks(rotation=0)
plt.title('Job Level')

plt.subplot(1,3,3)
sns.distplot(data['DistanceFromHome'], color='blue')
plt.xlim(0,30)
plt.title('Distance From Home')

plt.show()

# %% [markdown]
# - Business Travel: Most employee in this company are rarely doing business travel
# - Job Level: Job level distribution in this company is normal (more number of employee in lower level)
# - Distance From Home: Most employee in this company are living near from office

# %%
plt.figure(figsize=(18,6))

plt.subplot(1,3,1)
sns.countplot(x='EnvironmentSatisfaction',data=data)
plt.title('Environment Satisfaction')

plt.subplot(1,3,2)
sns.countplot(x='JobSatisfaction',data=data)
plt.title('Job Satisfaction')

plt.subplot(1,3,3)
sns.countplot(x='WorkLifeBalance',data=data)
plt.title('Work Life Balance')

plt.show()

# %% [markdown]
# - Environment Satisfaction: Most employees in this company feel satisfied with the environment in company
# - Job Satisfaction: Most employees feel satisfied with their job
# - Work Life Balance: Most employees feel their work-life already balanced

# %% [markdown]
# ## Multivariate (2 Features)

# %%
data.drop(['EmployeeID'], axis=1, inplace=True)

# %%
# data['Attrition']= data['Attrition'].map({'No': 0, 'Yes': 1})

# %%
# Age Column Binning 
age_bin = [10, 20, 30, 40, 50, data['Age'].max()]
labels = ['10-20', '21-30', '31-40', '41-50', '51-60']
data['Age_Bin'] = pd.cut(data['Age'], bins=age_bin, labels = labels)

data['Age_Bin']
# Out:
# 0       51-60
# 1       31-40
# 2       31-40
# 3       31-40
# 4       31-40
#         ...
# 4405    41-50
# 4406    21-30
# 4407    21-30
# 4408    41-50
# 4409    31-40
# Name: Age_Bin, Length: 4410, dtype: category
# Categories (5, object): [10-20 < 21-30 < 31-40 < 41-50 < 51-60]

# %%
plt.figure(figsize= (35,30))
sns.heatmap(data.corr(), annot=True, annot_kws={'size':15})
plt.title('Correlation Matrix', fontweight='bold', fontsize='18')
plt.show()

# %%
# data['Attrition']= data['Attrition'].map({'No': 0, 'Yes': 1})

# correlation= data.corr()
# correlation['Attrition'].sort_values(ascending = False)[1:]

#columns ordered from the higest posisve correlation to the lowest

# %%
graphs = ['Age_Bin', 'MaritalStatus', 'Gender', 'Department', 'JobRole', 'EducationField']
plt.figure(figsize=(20,15))
for index, item in enumerate(graphs):
    plt.subplot(2,3,index+1)
    ax = sns.countplot(x=item, hue='Attrition', data=data, palette='magma')
    if index+1>3: plt.xticks(rotation=90)
    index = int(len(ax.patches)/2)
    for left,right in zip(ax.patches[:index], ax.patches[index:]):
        left_height = left.get_height()
        right_height = right.get_height()
        total = left_height + right_height
        ax.text(left.get_x() + left.get_width()/2., left_height + 20, '{:.0%}'.format(left_height/total), ha="center")
        ax.text(right.get_x() + right.get_width()/2., right_height + 20, '{:.0%}'.format(right_height/total), ha="center")
plt.show()

# %% [markdown]
# Insight:
# - Age Group: 23% of employees in age group 21-30 left the company
# - Marital Status: 25% of employees with single marital status left the company
# - Gender: 17% of male company left the company
# - Department: 29% of employees in Human Resources department left the company
# - Job Role: 23% of research director left the company
# - Education Field: 40% of employee who studied Human Resources left the company

# %%
graphs = ['BusinessTravel', 'EnvironmentSatisfaction', 'JobSatisfaction', 'YearsSinceLastPromotion', 
          'YearsWithCurrManager', 'WorkLifeBalance']
plt.figure(figsize=(20,15))
for index, item in enumerate(graphs):
    plt.subplot(2,3,index+1)
    ax = sns.countplot(x=item, hue='Attrition', data=data, palette='magma')
    if index+1>3: plt.xticks(rotation=90)
    index = int(len(ax.patches)/2)
    for left,right in zip(ax.patches[:index], ax.patches[index:]):
        left_height = left.get_height()
        right_height = right.get_height()
        total = left_height + right_height
        ax.text(left.get_x() + left.get_width()/2., left_height + 20, '{:.0%}'.format(left_height/total), ha="center")
        ax.text(right.get_x() + right.get_width()/2., right_height + 20, '{:.0%}'.format(right_height/total), ha="center")
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
plt.figure(figsize=[28,15])
years_att= sns.countplot(x= "YearsAtCompany",hue= 'Attrition',data= data)
plt.ylabel('Number Of Employees')
plt.title('Years At Company for Attrition', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Years At Company for Attrition')

# %% [markdown]
# - The longer the employees are in the company, their desire to left company will be less than employees with shorter duration in company

# %%
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
sns.distplot(data[data['Attrition']=='Yes']['MonthlyIncome'], color='red')
plt.title('Monthly Income for Attrition (Yes)', fontsize=14)

plt.subplot(1,2,2)
sns.distplot(data[data['Attrition']=='No']['MonthlyIncome'], color='blue')
plt.title('Monthly Income for Attrition (No)', fontsize=14)

plt.show()

# %% [markdown]
# - Employee with lower income has more tendency to leave the company

# %%
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
sns.distplot(data[data['Attrition']=='Yes']['PercentSalaryHike'], color='red')
plt.title('Percent Salary Hike for Attrition (Yes)', fontsize=14)

plt.subplot(1,2,2)
sns.distplot(data[data['Attrition']=='No']['PercentSalaryHike'], color='blue')
plt.title('Percent Salary Hike for Attrition (No)', fontsize=14)

plt.show()

# %% [markdown]
# - Employee with lower percent salary hike has more tendency to leave the company

# %%
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
sns.distplot(data[data['Attrition']=='Yes']['YearsAtCompany'], color='red')
plt.title('Years At Company for Attrition (Yes)', fontsize=14)

plt.subplot(1,2,2)
sns.distplot(data[data['Attrition']=='No']['YearsAtCompany'], color='blue')
plt.title('Years At Company for Attrition (No)', fontsize=14)

plt.show()

# %% [markdown]
# - Employe with longer years in company has less tendency to leave the company

# %%
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
sns.distplot(data[data['Attrition']=='Yes']['YearsWithCurrManager'], color='red')
plt.title('Years With Current Manager for Attrition (Yes)', fontsize=14)

plt.subplot(1,2,2)
sns.distplot(data[data['Attrition']=='No']['YearsWithCurrManager'], color='blue')
plt.title('Years With Current Manager for Attrition (No)', fontsize=14)

plt.show()

# %% [markdown]
# - Employee who stay in a long time with a manager have less tendency to leave company, but there is an anomaly in range 6-7.5 years

# %%
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
sns.distplot(data[data['Attrition']=='Yes']['YearsSinceLastPromotion'], color='red')
plt.title('Years Since Last Promotion for Attrition (Yes)', fontsize=14)

plt.subplot(1,2,2)
sns.distplot(data[data['Attrition']=='No']['YearsSinceLastPromotion'], color='blue')
plt.title('Years Since Last Promotion for Attrition (No)', fontsize=14)

plt.show()

# %% [markdown]
# ## Multivariate (3 Features)

# %%
pd.crosstab(index=[data['MaritalStatus'], data['Attrition']],
            columns=[data['Gender']]).T
# Out:
# MaritalStatus Divorced     Married      Single
# Attrition           No Yes      No  Yes     No  Yes
# Gender
# Female             333  33     738  108    423  129
# Male               549  66    1029  144    627  231

# %%
marit_gender_att = sns.catplot(x="MaritalStatus", hue="Gender", col="Attrition",
                   data= data, kind="count", height=4, aspect=.7);

# %%
gender_education = sns.catplot(x="Education", hue="Gender", col="Attrition",
                data= data, kind="count", height=4, aspect=.7);

# %%
data.drop(['Age_Bin'], axis=1, inplace=True)

# %%
data.to_csv('/Users/cahyopambudiutomo/Documents/Purwadhika/Final Project/JCDS Cahyo/Dataset/data_clean.csv', index = False)

# %% [markdown]
# # Room For Improvement
#
# Based on EDA above, employee who has higher risk to leave the company are those who have the following criteria:
# 1. Age: Employee in age range 21-30 are at higher risk to leave the company
# 2. Marital Status: Employee who are still single are at higher risk to leave the company
# 3. Business Travel: Emplpoyee with higher travel frequency are at higher risk to leave the company
# 4. Environment Satisfaction, Work Life Balance, and Job Satisfaction: The lower the value an employee got, the higher is the risk to leave the company
# 5. Years Since Last Promotion: Employee who didn't get promotion more than 5 years are at higher risk to leave the company
# 6. Years With Current Manager: More the time spend with their current manager, more less the risk to leave the company
#
# If the Company (Especially HR team) want to keep their current employee, they need to be aware for the cause why the employee left the company and can make a prevention move to keep their employee (such as not making an employee has more business travel time than the others)
